# %%
import pandas as pd
import numpy as np

# %%
interview = pd.read_csv('Interview.csv')
# set seed for reproducibility
np.random.seed(0)

# %%
pd.set_option('display.max_columns', None)
interview.head()
# Out:
#   Date of Interview Client name         Industry Location  \
# 0        13.02.2015     Hospira  Pharmaceuticals  Chennai
# 1        13.02.2015     Hospira  Pharmaceuticals  Chennai
# 2        13.02.2015     Hospira  Pharmaceuticals  Chennai
# 3        13.02.2015     Hospira  Pharmaceuticals  Chennai
# 4        13.02.2015     Hospira  Pharmaceuticals  Chennai
#
#   Position to be closed Nature of Skillset    Interview Type Name(Cand ID)  \
# 0   Production- Sterile            Routine  Scheduled Walkin   Candidate 1
# 1   Production- Sterile            Routine  Scheduled Walkin   Candidate 2
# 2   Production- Sterile            Routine  Scheduled Walkin   Candidate 3
# 3   Production- Sterile            Routine  Scheduled Walkin   Candidate 4
# 4   Production- Sterile            Routine  Scheduled Walkin   Candidate 5
#
#   Gender Candidate Current Location Candidate Job Location Interview Venue  \
# 0   Male                    Chennai                  Hosur           Hosur
# ...

# %%
columns_to_keep = ['Date of Interview', 'Industry', 'Name(Cand ID)']
df = interview[columns_to_keep]
df.head()
# Out:
#   Date of Interview         Industry Name(Cand ID)
# 0        13.02.2015  Pharmaceuticals   Candidate 1
# 1        13.02.2015  Pharmaceuticals   Candidate 2
# 2        13.02.2015  Pharmaceuticals   Candidate 3
# 3        13.02.2015  Pharmaceuticals   Candidate 4
# 4        13.02.2015  Pharmaceuticals   Candidate 5

# %%
interview.describe(include = ['O'])
# Out:
#        Date of Interview              Client name Industry Location  \
# count               1233                     1234     1233     1233
# unique                96                       16        7       11
# top           06.02.2016  Standard Chartered Bank     BFSI  Chennai
# freq                 220                      904      949      754
#
#        Position to be closed          Nature of Skillset     Interview Type  \
# count                   1233                        1233               1233
# unique                     7                          92                  6
# top                  Routine  JAVA/J2EE/Struts/Hibernate  Scheduled Walk In
# freq                    1023                         220                456
#
#         Name(Cand ID) Gender Candidate Current Location  \
# count            1233   1233                       1233
# unique           1233      2                         10
# top     Candidate 622   Male                    Chennai
# ...

# %%
interview.columns
# Out:
# Index(['Date of Interview', 'Client name', 'Industry', 'Location',
#        'Position to be closed', 'Nature of Skillset', 'Interview Type',
#        'Name(Cand ID)', 'Gender', 'Candidate Current Location',
#        'Candidate Job Location', 'Interview Venue',
#        'Candidate Native location',
#        'Have you obtained the necessary permission to start at the required time',
#        'Hope there will be no unscheduled meetings',
#        'Can I Call you three hours before the interview and follow up on your attendance for the interview',
#        'Can I have an alternative number/ desk number. I assure you that I will not trouble you too much',
#        'Have you taken a printout of your updated resume. Have you read the JD and understood the same',
#        'Are you clear with the venue details and the landmark.',
#        'Has the call letter been shared', 'Expected Attendance',
#        'Observed Attendance', 'Marital Status', 'Unnamed: 23', 'Unnamed: 24',
# ...

# %%
#interview['Location'].corr(interview['Interview Type'])

# %%
interview.Location.value_counts()
# Out:
# Chennai       754
# Bangalore     292
# chennai        86
# Hyderabad      38
# Gurgaon        33
# Noida          15
# - Cochin-       9
# chennai         3
# Delhi           1
# CHENNAI         1
# Gurgaonr        1
# Name: Location, dtype: int64

# %%
# get the number of missing data points per column
missing_values_count = interview.isnull().sum()

missing_values_count
# Out:
# Date of Interview                                                                                        1
# Client name                                                                                              0
# Industry                                                                                                 1
# Location                                                                                                 1
# Position to be closed                                                                                    1
# Nature of Skillset                                                                                       1
# Interview Type                                                                                           1
# Name(Cand ID)                                                                                            1
# Gender                                                                                                   1
# ...

# %%
df = pd.read_csv('abc.csv')

# %%
df.head()
# Out:
#    A    B    C
# 0  1  123  App
# 1  2  312  Box
# 2  3  123  Box
# 3  4  122  Box
# 4  5  333  App

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi

# %%
df.describe()
# Out:
#               A           B
# count  5.000000    5.000000
# mean   3.000000  202.600000
# std    1.581139  109.705515
# min    1.000000  122.000000
# 25%    2.000000  123.000000
# 50%    3.000000  123.000000
# 75%    4.000000  312.000000
# max    5.000000  333.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.boxplot(x=df['C'], y=df['B'], showmeans=True)
plt.show()

# %%
#ANOVA F Test

model = smf.ols(formula='B ~ C', data=df)
results = model.fit()
print (results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      B   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                 -0.274
# Method:                 Least Squares   F-statistic:                    0.1403
# Date:                Tue, 10 Apr 2018   Prob (F-statistic):              0.733
# Time:                        21:06:37   Log-Likelihood:                -29.912
# No. Observations:                   5   AIC:                             63.82
# Df Residuals:                       3   BIC:                             63.04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    228.0000     87.551      2.604      0.080     -50.625     506.625
# ...
